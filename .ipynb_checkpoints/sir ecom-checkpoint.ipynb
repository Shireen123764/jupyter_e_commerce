# %%
def rate_option(var):
    if var=="pulses":
        rate=500
    elif var=="spices":
        rate=150
    elif var=="dairy":
        rate=300
    elif var=="rice":
        rate=4000
    elif var=="wheat":
        rate=3000
    elif var=="computer":
        rate=20000
    elif var=="mobile_phone":
        rate=50000
    elif var=="led":
        rate=60000
    elif var=="graphic_card":
        rate=50000
    elif var=="charger":
        rate=1200
    elif var=="mango":
        rate=200
    elif var=="potato":
        rate=100
    elif var=="apple":
        rate=180
    elif var=="spinach":
        rate=250
    elif var=="tomato":
        rate=150
    elif var=="green_chilli":
        rate=100
    elif var=="grapes":
        rate=400
    elif var=="onion":
        rate=120
    elif var=="pent":
        rate=4000  
    elif var=="shirt":
        rate=3000
    elif var=="belt":
        rate=500 
    elif var=="hoodies":
        rate=3000
    elif var=="jackets":
        rate=5000  
    elif var=="muffler":
        rate=1500
        
    else:
        print("invalid value, please check your outer program!")
        rate=0
    return rate
   
def calc_total(cart,total):
    print(f"Your Total cart is:")
    for i in range(0,len(cart)):
        print(f" {i+1}-{cart[i]}  | Rs.{total[i]}")
    print(f"Your Total items are {len(cart)} and Rs.{sum(total)}/ ")

def modify(cart,total):
        rem=input(f" Which item for a cart you want to remove? {cart} | please mention the product exactly:")
        item_index=cart.index(rem)
        cart.remove(rem)
        total.pop(item_index)

def bucket(cat):
    if cat=="1":
        bucket=["pulses","spices","dairy","rice","wheat"]
    elif cat=="2":
        bucket=["computer","mobile_phone","led","graphic_card","charger"]
    elif cat=="3":
        bucket=["mango","potato","apple","spinach","tomato","green_chilli","grapes","onion"]
    elif cat=="4":
        bucket=["pent","shirt","belt","trouser","hodies","jacket","muffler"]
        
    else:
        print("Invalid input!")
    return bucket

def engine(select,category):
        while True:
            print(f"Welcome to {category} section")
            for i in bucket(select):
                print(f"{bucket(select).index(i)+1}:{i}")
            var=input("Please mention what your want to buy from above list?").lower()
            rates=rate_option(var)
            if var in bucket(select):
                cart.append(var)
                total.append(rates)
                print("++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++")
                print(f"bought item {var}, Rs.{rates}, Your Total Items are {cart} and total amount is {sum(total)}")
                print("++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++")
                rerun=input(f"Do you want to add more from {category}? (yes or no):").lower()
                if rerun=="yes":
                    continue
                else:
                    print("++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++")
                    print(f"Ok Thank you for shopping {category}!")
                    break
            else:
                print("++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++")
                print("item not found in the bucket, Please select from below")
                continue

#### program below ####
cart=[] #all cart
total=[] #all total

print("Welcome to ecomerce store!")

while True:
    select=input("Which category you want to buy? \n1.grocery \n2.electronic \n3.fruit and veg \n4.clothing:")
    print("++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++")
    
    if select=="1":
        engine(select,"Grocery")
        
    elif select=="2":
        engine(select,"Electronics")

    elif select=="3":
        engine(select,"Fruit and Vegetable")
    elif select=="4":
        engine(select,"clothing")
    
    else:
        print("invalid input!")
        rerun=input("Do you want try again? (yes or no):").lower()
        if rerun=="yes":
            continue
        else:
            print("Thank you! Bye!")
            break
    rerun=input("Do you want to add more from store? \n(yes) for Continue to store \n(no) for exiting for the total bill \n(mod) for modifying your cart!: \n:").lower()
    if rerun=="yes":
        continue
    elif rerun=="mod":
        modify(cart,total)
    else:
        print("Thank you for Shopping!")
    calc_total(cart,total)
    break
# Out:
# Welcome to ecomerce store!
# Which category you want to buy?
# 1.grocery
# 2.electronic
# 3.fruit and veg
# 4.clothing: 3
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Welcome to Fruit and Vegetable section
# 1:mango
# 2:potato
# 3:apple
# 4:spinach
# 5:tomato
# 6:green_chilli
# 7:grapes
# 8:onion
# Please mention what your want to buy from above list? apple
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# bought item apple, Rs.180, Your Total Items are ['apple'] and total amount is 180
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Do you want to add more from Fruit and Vegetable? (yes or no): yes
# Welcome to Fruit and Vegetable section
# 1:mango
# 2:potato
# 3:apple
# 4:spinach
# 5:tomato
# 6:green_chilli
# 7:grapes
# 8:onion
# Please mention what your want to buy from above list? green_chilli
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# bought item green_chilli, Rs.100, Your Total Items are ['apple', 'green_chilli'] and total amount is 280
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
